# %% [markdown]
# # Python Indentation

# %%
##### Indentation refers to the spaces at the beginning of a code line.
##### at least one space should be in the beginning of a code line

# %%
if(5>2):
    print("true")
# Out:
# true

# %%
if(5>2):
print("true")                    #####  if we miss identation it will show error
# Out:
#   File "<ipython-input-5-79917e40b43b>", line 2
#     print("true")                    #####  if we miss identation it will show error
#         ^
# IndentationError: expected an indented block

# %% [markdown]
# ### python variable

# %%
# variables are created when you assign a value to it

# %% [markdown]
# ### comment

# %%
 ######  you can add a multiline string (triple quotes) in your code, and place your comment inside it

# %%
"""   this os a comment
writttn in more than
one line"""
# Out:
# '   this os a comment\nwritttn in more than\none line'

# %% [markdown]
# ##  casting

# %%
# casting is done using constructor function

# %%
### If you want to specify the data type of a variable, this can be done with casting.

# %%
###  it is also used to convert one data  type into another

# %% [markdown]
# x = str(3)    # x will be '3'
# y = int(3)    # y will be 3
# z = float(3)  # z will be 3.0

# %%
x =  9

# %%
x = str(9)

# %%
print(x)
# Out:
# 9

# %%
x =float(9)

# %%
x
# Out:
# 9.0

# %% [markdown]
# ###  unpack a list

# %%
fruits = ["orange","banana","mango"]

# %%
x,y,z = fruits

# %%
print(x)
# Out:
# orange

# %%
print(y)
# Out:
# banana

# %%
print(z)
# Out:
# mango

# %% [markdown]
# ###  to combine both text and variable python uses + sign

# %% [markdown]
# ### to combine both string and number you will see an error

# %% [markdown]
# ### Global Variables

# %%
x = "awesome"

def myfunc():
  print("Python is " + x)

myfunc()
# Out:
# Python is awesome

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %%
def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %%
### square brackets can be used to access the elements of the string

# %%
a  ='hello world'

# %%
print(a[2])
# Out:
# l

# %% [markdown]
# ### loop

# %% [markdown]
# for x in "banana":
#      print(x)

# %% [markdown]
# ### length

# %%
len(x)
# Out:
# 1

# %%
len(a)
# Out:
# 11

# %%
txt = "I am a super hero"

# %%
###  in gives true or false

# %% [markdown]
# ### to check --------"in" is used

# %%
###  if print whatever you write in print functionas below

# %%
print("am"  in  txt)
# Out:
# True

# %% [markdown]
# ### ------   if

# %%
text = "I am an old man"

# %%
if "am" in text:
    print("yes")
# Out:
# yes

# %% [markdown]
# ### slicing

# %%
###  gives range f characters or integers

# %%
print(a[2:4])
# Out:
# ll

# %%
print(a[:4])
# Out:
# hell

# %%
print(a[2:])
# Out:
# llo world

# %%
print(a[-5:-3])
# Out:
# wo

# %% [markdown]
# ###  modify strings

# %%
print(a.upper())
# Out:
# HELLO WORLD

# %%
print(a.lower())
# Out:
# hello world

# %%
####  to remove whitespace

# %%
a  = "    hello, world!    "

# %%
a.strip()
# Out:
# 'hello, world!'

# %%
#####  replace string letters

# %%
print(a.replace("h" , "J"))
# Out:
#     Jello, world!

# %%
### split string

# %%
### The split() method returns a list where the text between the specified separator becomes the list items

# %%
print(a.split())
# Out:
# ['hello,', 'world!']

# %% [markdown]
# ### string format

# %%
### we can not combine string and integer

# %%
#  but we can combine string and number by  format method

# %%
age = 45

# %% [markdown]
# text1 = "I am a super boy,and I am {}"

# %%
print(text1.format(age))
# Out:
# I am a super boy,and I am 45

# %%
 itemnumber = 123
 quantity = 1234
 price = 234

# %%
text2 ="the product itemnumber is {},it's quantity is {} and its price is $ {}"

# %%
print(text2.format(itemnumber,quantity,price))
# Out:
# the product itemnumber is 123,it's quantity is 1234 and its price is $ 234

# %% [markdown]
# ### escape character

# %%
#     text3 = "We are the so-called "Vikings" from the north."------------------error

# %%
#   to not get error we need to use the symbol  ----- \"

# %%
text3= "We are the so-called \"Vikings\" from the north."

# %% [markdown]
# # booleans

# %%
# booleans represent two values - "true"  or "false"

# %%
# when we compare the two expressions we get the result as true or false

# %%
print(10>9)
# Out:
# True

# %%
# when we run a condition in an if statement the result is obtained as true or false

# %%
a = 20
b = 1
if(b>a):
    print("it is true")
else:
     print("it is not")
# Out:
# it is not

# %%
print(bool("hello"))
# Out:
# True

# %%
print(bool(15))
# Out:
# True

# %%
x = "hello"           ## give true when used in bool

# %%
y = 13                  ## give true when used in bool

# %%
bool(x)
# Out:
# True

# %%
##  most values are returned as true

# %%
# almost any value is returned as true ifit has some sor of content

# %%
# any string is true , except empty string

# %%
# any number is true except 0

# %%
# any list,tuples ,set , dictionaries are true except ones

# %%
bool("")
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
##       class_len_ will also give false

# %%
class myclass():
    def _len_(self):
       return 0
myobj = myclass()
print(bool(myobj))
# Out:
# True

# %%
class myclass():
  def __len__(self):
    return 0

myobj = myclass()
print(bool(myobj))
# Out:
# False

# %%
def myfunc():
    return true
print(bool("myfunc"))
# Out:
# True

# %%
def myFunction() :
  return True

if myFunction():
  print("YES!")
else:
  print("NO!")
# Out:
# YES!

# %%
#to check if an object is of certain data type or not ---  isinstance()

# %%
x = 200
print(isinstance(x,int))
# Out:
# True

# %% [markdown]
# ## python operators

# %%
# modulus

# %%
x = 24
y = 4

# %%
x % y
# Out:
# 0

# %%
# exponenation

# %%
x**y
# Out:
# 331776

# %%
#  floor- x//y

# %%
x//y         #The floor() method returns the floor of x i.e. the largest integer not greater than x.
# Out:
# 6

# %%
##  and operator --   returns true if both statements are true

# %%
## or operator --  returns true if only one statement is true

# %%
##  not operator -- returns true if statments is false  and revers

# %%
x = 3
print(x>2 and x<12)
# Out:
# True

# %%
x = 4
print(x < 3 or x == 4)
# Out:
# True

# %%
x = 4 
print(not(x > 3 and x < 10))
# Out:
# False

# %%
# in operator ---returns true if a specified value is present in a object
# not in ---returns true if a specified value is not present in  a  object

# %%
x = "string"

print("rin" in x)
# Out:
# True

# %% [markdown]
# ## list

# %%
# list  can hold 4 data types of python i.e, data,tuple,set,dictionary

# %%
# list are creaated in square brackets

# %%
## lists can be changed

# %%
thislist = ['apple','banana','orange']

# %%
print(thislist)
# Out:
# ['apple', 'banana', 'orange']

# %%
# list items are changeable and allow duplicate values to come again and execute
#  list items are ordered i.e, it will not change when we add a new item to a list  rather it will be added at the end ofthe list
# to determine number ofitems in a list use len()
# list can contain any data type i.e, int , boolean , string

# %%
# to construct a string in a list use -----    (())

# %%
thislist = list(("apple", "banana", "cherry")) # note the double round-brackets
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# ### python collection arrays

# %%
#There are four collection data types in the Python programming language:

#List is a collection which is ordered and changeable. Allows duplicate members.
#Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
#Set is a collection which is unordered and unindexed. No duplicate members.
#Dictionary is a collection which is unordered and changeable. No duplicate members.

# %% [markdown]
# ### access items

# %%
# -1 , -2 ,refers to the  last and the second last items

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[-1])
# Out:
# cherry

# %%
list = ["mango", "apple", "banana","pineapple",23,"@"]

# %%
print(list[2:5])
# Out:
# ['banana', 'pineapple', 23]

# %%
#The search will start at index 2 (included) and end at index 5 (not included).

# %% [markdown]
# ##  check if items exist

# %%
list = ["mango", "apple", "banana","pineapple",23,"@"]
if "@" in list:
    print("yes")
# Out:
# yes

# %% [markdown]
# ### change item view

# %%
list = ["mango", "apple", "banana","pineapple",23,"@"]

# %%
list[2] = "blackapple"

# %%
print(list)
# Out:
# ['mango', 'apple', 'blackapple', 'pineapple', 23, '@']

# %%
list[2:4] =  ["apple2","apple3","apple4"]

# %%
print(list)
# Out:
# ['mango', 'apple', 'apple2', 'apple3', 'apple4', 23, '@']

# %%
### Insert Items
### To insert a new list item, without replacing any of the existing values, we can use the insert() method.

# %%
list = ["mango", "apple", "banana","pineapple",23,"@"]
list.insert(2,"guava")

# %%
print(list)
# Out:
# ['mango', 'apple', 'guava', 'banana', 'pineapple', 23, '@']

# %%
## # to add an item at the end of the list use "append"

# %%
list.append("watermelon")

# %%
print(list)
# Out:
# ['mango', 'apple', 'guava', 'banana', 'pineapple', 23, '@', 'watermelon']

# %%
## Extend List
## To append elements from another list to the current list, use the extend() method.

# %%
list = ["mango", "apple", "banana","pineapple",23,"@"]
tropical = ["hippo","zebra","cobra"]

# %%
list.extend(tropical)

# %%
print(list)
# Out:
# ['mango', 'apple', 'banana', 'pineapple', 23, '@', 't', 'r', 'o', 'p', 'i', 'c', 'a', 'l', 'hippo', 'zebra', 'cobra']

# %%
###  remove  specified elements from a list

# %%
list = ["mango", "apple", "banana","pineapple",23,"@"]
list.remove("banana")
print(list)
# Out:
# ['mango', 'apple', 'pineapple', 23, '@']

# %%
# Remove Specified Index
# The pop() method removes the specified index.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
#Remove the last item:

thislist = ["apple", "banana", "cherry"]
thislist.pop()
print(thislist)
# Out:
# ['apple', 'banana']

# %%
#  del removes speccified  items from  list

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
for x in thislist:
    print(x)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ### Iterable is an object, which one can iterate over. It generates an Iterator when passed to iter() method. Iterator is an object, which is used to iterate over an iterable object using __next__() method. ... Note that every iterator is also an iterable, but not every iterable is an iterator.

# %%
## to create iterator

# %%
#  iterabble can iterate objects onlylike list,tuple,set,etc.

# %%
# use range()  and len()  function to create iterable

# %%
nums = [7,6,5,4]
it = iter(nums)         # iter == iterator
print(it)

print(next(it))
print(next(it))
# Out:
# ...
# 7
# 6

# %%
newlist =[x for x in range(10) if x<5]
print(newlist)
# Out:
# [0, 1, 2, 3, 4]

# %%
thislist = ["apple", "banana", "cherry"]
for i in range(len(thislist)):
    print(thislist[i])
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
i = 0
while i < len(thislist):
    print(thislist[i])
    i = i + 1
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
newlist = [x for x in thislist if x != "apple"]
print(newlist)
# Out:
# ['banana', 'cherry']

# %% [markdown]
# ##  sort

# %%
# it wil sort()  the list alphanumerically by default in ascending order

# %%
thislist = ["apple", "banana", "cherry"]
thislist.sort()
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist2 = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist2.sort()
print(thislist2)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
thislist2 = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist2.sort(reverse = True)
print(thislist2)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
###  customize sort function

# %%
###  to customize your own sort function use key = function
###  the function will return a list that will be used to sort the list(the lowest number first)

# %%
def myfunc(n):
    return abs(n-50)
thislist = [100,90,80,70,60]
thislist.sort( key = myfunc)
print(thislist)
# Out:
# [60, 70, 80, 90, 100]

# %%
##  join list

# %%
list1 = [1,2,3]
list2 = ["a","b","c"]
list3 = list2 + list1
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %% [raw]
#  for x in list2:
#  list1.append(x)
#  print(list1)

# %%
list1.extend(list2)
print(list1)
# Out:
# [1, 2, 3, 'a', 'b', 'c']

# %% [markdown]
# ## tuples

# %%
## A tuple is a collection which is ordered and unchangeable.
# Tuples are written with round brackets.

# %%
thistuple = ("apple", "mango","banana")
print(thistuple)
# Out:
# ('apple', 'mango', 'banana')

# %%
#type of tuple

# %%
tuple=("apple",)
print(type(tuple))
# Out:
# <class 'tuple'>

# %%
##  creating tuple with one item ,then, we have to add comma after the item otherwisepython will not recogniseit as a tuple

# %%
## not a tuple
thistuple1 = ("apple")

# %%
print(type(thistuple1))
# Out:
# <class 'str'>

# %%
###  to construct tuple
thistuple = tuple(("apple", "banana", "cherry")) # note the double round-brackets
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
## Python Collections (Arrays)
## There are four collection data types in the Python programming language:

#List is a collection which is ordered and changeable. Allows duplicate members.
#Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
#Set is a collection which is unordered and unindexed. No duplicate members.
#Dictionary is a collection which is unordered and changeable. No duplicate members.

# %%
###  change tuple value

# %%
x = ("apple", "banana","mango")
y = list(x)
y[1] = "kiwi"
y = tuple(y)
print(y)
# Out:
# ('apple', 'kiwi', 'mango')

# %%
#  y.append("kiwa")
#print(y)

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

(green, yellow, *red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %%
thistuple = ("apple", "banana", "cherry")
i = 0
while i < len(thistuple):
  print(thistuple[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
fruits.count("apple")      ####  returns the specified number of times a specified vlaue occurs
# Out:
# 1

# %%
fruits.index("cherry")   ###  returns the position of the specified vslue ask
# Out:
# 2

# %% [markdown]
# ## sets

# %%
## sets are written with curly brackets

# %%
theset ={"apple","apple", "banana"}
print(theset)
# Out:
# {'banana', 'apple'}

# %%
##  to construct a set

# %%
theset2 = set(("apple","apple", "banana"))
print(theset2)
# Out:
# {'banana', 'apple'}

# %%
theset2.add("orange")
print(theset2)
# Out:
# {'banana', 'orange', 'apple'}

# %%
###  to add items from another set to current set use "update" method

# %%
theset2.update(theset)

# %%
print(theset2)
# Out:
# {'orange', 'apple', 'banana'}

# %%
##  to remove one item of a set use discard

# %%
theset2.discard("banana")
print(theset2)
# Out:
# {'orange', 'apple'}

# %%
##  using pop() function removes the last item of the set

# %%
thisset = {"apple", "banana", "cherry"}
x = thisset.pop()

# %%
print(x)
# Out:
# banana

# %%
for x in theset:
    print(x)
# Out:
# banana
# apple

# %%
theset ={"apple","apple", "banana"}

# %% [markdown]
# ###  join two sets

# %%
####  use union function to join the set

# %%
set1 = {1,2,3}
set2 ={5,6,7}
x = set1.union(set2)
print(x)
# Out:
# {1, 2, 3, 5, 6, 7}

# %%
x = set1.update(set2) 
print(x)
# Out:
# None

# %%
## Keep ONLY the Duplicates

# %%
theset2 = {"apple","mango"}

# %%
y = theset.intersection_update(theset2)
print(y)
# Out:
# None

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
x.intersection_update(y)
print(x)
# Out:
# {'apple'}

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}

z = x.intersection(y)

print(z)
# Out:
# {'apple'}

# %%
#  Keep All, But NOT the Duplicates

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
x.symmetric_difference_update(y)
print(x)
# Out:
# {'google', 'banana', 'cherry', 'microsoft'}
