# %%
##  inheritance

# %%
## polymorphism

# %%
##  supervised learning

# %%
##   unsupervised learning

# %% [markdown]
# #   library

# %%
##  scripts

# %%
##   modules

# %%
##  package

# %%
## libraries

# %% [markdown]
# ###  python libraries

# %%
##  Tensor Flow                #####  important  
###  can be accessed  by   typing on google chrome ------    Tensor Flow documentation

# %%
##  Scikit-Learn----
##   numpy::::,,,,,,,,, 
### SciPy

# %%
##  keras

# %%
##  Pytorch

# %%
## LightGBM

# %%
## Eli5

# %%
## Theano

# %%
##  Pandas

# %%
import string

# %%
print("the lower ascii letters are" , string.ascii_lowercase)
# Out:
# the lower ascii letters are abcdefghijklmnopqrstuvwxyz

# %%
print(string.capwords("capitalise the cap words please"))
# Out:
# Capitalise The Cap Words Please

# %%
###  to learn the contents of a library
help(string)  
###       help(library_name)     
####   use help to learn contents about any library module
# Out:
# Help on module string:
#
# NAME
#     string - A collection of string constants.
#
# MODULE REFERENCE
#     https://docs.python.org/3.7/library/string
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Public module variables:
#
#     whitespace -- a string containing all ASCII whitespace
#     ascii_lowercase -- a string containing all ASCII lowercase letters
#     ascii_uppercase -- a string containing all ASCII uppercase letters
#     ascii_letters -- a string containing all ASCII letters
#     digits -- a string containing all ASCII decimal digits
#     hexdigits -- a string containing all ASCII hexadecimal digits
#     octdigits -- a string containing all ASCII octal digits
# ...

# %% [markdown]
# ###   import specific items from a library module to shorten programs

# %%
##   use from...impor...  to load only specific items from a library module

# %%
from string import ascii_letters print('The ASCII letters are',ascii_letters)
# Out:
#   File "<ipython-input-69-2ff7429c2aa1>", line 1
#     from string import ascii_letters print('The ASCII letters are',ascii_letters)
#                                          ^
# SyntaxError: invalid syntax

# %%
###   create an alias for a library module  when importing it to shorten programs.

# %%
##  use import...as...  to give a library a  short alias while importing it

# %%
import string as s print(s.capwords('capitalise the sentence again please'))
# Out:
#   File "<ipython-input-72-e5cf4599e539>", line 1
#     import string as s print(s.capwords('capitalise the sentence again please'))
#                            ^
# SyntaxError: invalid syntax
