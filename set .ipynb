# %%
#  1. Write a Python program to create a set. 
def create_set(str1):
        return set(str1)
str1 = "a,b,c,d"
A = create_set(str1)
a= create_set([0,1,2,3])
a,A
# Out:
# ({0, 1, 2, 3}, {',', 'a', 'b', 'c', 'd'})

# %%
#  2. Write a Python program to iterate over sets.
n = set("swetanshu")
n
for i in n:
    print(i)
# Out:
# h
# w
# a
# e
# s
# u
# t
# n

# %%
#  3. Write a Python program to add member(s) in a set.
a = "swetanshu"
a = set(a)
def add_items(x,y):
    return a.update([x,y])
add_items("raj","pandey")
a
# Out:
# {'a', 'e', 'h', 'n', 'pandey', 'raj', 's', 't', 'u', 'w'}

# %%
# 4 .. Write a Python program to remove item(s) from set
b = "my name is swetanshu pandey"
b = b.split(" ")
b= set(b)
b.remove("pandey")
b = b.pop()
b
# Out:
# 'swetanshu'

# %%
#  5. Write a Python program to remove an item from a set 
#    if it is present in the set.
n= "my name is swetanshu"
n = n.split()
n = set(n)
n.discard("name")
n
# Out:
# {'is', 'my', 'swetanshu'}

# %%
# 6. Write a Python program to create an intersection of sets
set1 = {1,2,3}
set2 = {2,3,4}
set1.intersection(set2)
# Out:
# {2, 3}

# %%
#  7. Write a Python program to create a union of sets
s1 = {"my", "name", "is","swetanshu","pandey"}
s2 = {"my","name","is","raj","pandey"}
a = s1.union(s2)
a
# Out:
# {'is', 'my', 'name', 'pandey', 'raj', 'swetanshu'}

# %%
# 8. Write a Python program to create set difference.
s1 = {"my", "name", "am","is","swetanshu","pandey"}
s2 = {"my","name","is","raj","pandey"}
a= s1.difference(s2)
a
# Out:
# {'am', 'swetanshu'}

# %%
# 9. Write a Python program to create a symmetric difference
s1 = {"my", "name", "am","is","swetanshu","pandey"}
s2 = {"my","name","is","raj","pandey"}
a=s1.symmetric_difference(s2)
a
# Out:
# {'am', 'raj', 'swetanshu'}

# %%
# 10. Write a Python program to check if a set is a subset of
#      another set.
s1 = {1,2,3,4,5,6,7}
s2 = {2,3,4,5}
a = s2.issubset(s1)
a
# Out:
# True

# %%
# 11. Write a Python program to create a shallow copy of sets
set1 = {1,2,3}
set1.copy()
#  a = {1,2,3}
#b = a
#b.add("r")
#b
#a
# Out:
# {1, 2, 3}

# %%
# 12. Write a Python program to clear a set. 
s1 = {1,2,3,4,5,6,7}
s1.clear()
s1
# Out:
# set()

# %%
#  13. Write a Python program to use of frozensets
a = set()
a = set({1,2,3})
a.add(5)
a
a = frozenset({1,2,3})
a.add(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-b7ce3d4ce09a> in <module>
#       5 a
#       6 a = frozenset({1,2,3})
# ----> 7 a.add(5)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
# 14. Write a Python program to find maximum and the minimum value in a set.
a = set()
a = {1,2,3,4,100}
max(a)
min(a)
# Out:
# 1

# %%
#  15. Write a Python program to find the length of a set
a = {1,2,3,4,5,6,7}
len(a)
# Out:
# 7

# %%
# 16. Write a Python program to check if a given value is 
#    present in a set or not. 
a = {"my", "name","is","swetanshu","pandey"}
def present(str1,x):
    for i in a:
        if i==x:
            return "yes present"
        
present(a,"swetanshu")   
#  method 2
a = {"my", "name","is","swetanshu","pandey"}
print("my"  in a)
# Out:
# 'yes present'

# %%
#  17. Write a Python program to check if two given sets have 
#   no elements in common. 
a = {"my", "name","is","swetanshu","pandey"}
b = {"my", "name","is","raj","pandey"}
e= a.isdisjoint(b)
c = {1,2}
d = {3,4}
f = c.isdisjoint(d)
print(e,f)
# Out:
# False True

# %%
# 18. Write a Python program to check if a given set is 
#     superset of itself and superset of another given set
a = {"my", "name","is","swetanshu","pandey"}
b = {"my", "name","is","raj","pandey"}
b.issuperset(a)
# Out:
# False

# %%
#  19. Write a Python program to find the elements in a given 
#   set that are not in another set. 
a = {"my", "name","is","swetanshu","pandey"}
b = {"my", "name","is","raj","pandey"}
a.difference(b)
# Out:
# {'swetanshu'}

# %%
# 20. Write a Python program to check a  given set has no elements
#   in common with other given set.
a.isdisjoint(b)
# Out:
# False

# %%
#  21. Write a Python program to remove the intersection of a 2nd set from the 1st set.
a = {"my", "name","is","swetanshu","pandey"}
b = {"my", "name","is","raj","pandey"}
a.intersection_update(b)
