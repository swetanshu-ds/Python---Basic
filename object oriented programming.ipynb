# %%
class car:
    pass

# %%
audiq7 = car()

# %%
audiq7.milage = 10
audiq7.year = 2020
audiq7.make= 345
audiq7.model= "fsdf"

# %%
audiq7.milage
# Out:
# 10

# %%
audiq7.year
# Out:
# 2020

# %%
nano = car()

# %%
nano

# %%
nano.milage = 20
nano.year = 2020
nano.make = 234
nano.model = "sdfa"
nano.engineno = 141242514712

# %%
print(nano.milage,audiq7.milage)
# Out:
# 20 10

# %%
class car:
    def __init__(self,milage,year,make,model):
        self.milage = milage
        self.year = year
        self.make  = make
        self.make = model

# %%
nano1 = car(20,2020,3432,"223432f34")
audiq71 = car(10,2020,4543,"sdfff")

# %%
nano1.milage
# Out:
# 20

# %%
nano1 = car(20,2020,3432,"223432f34")
audiq71 = car(10,2020,4543,"sdfff")
nano2 = car(20,2020,3432,"223432f34")
audiq72 = car(10,2020,4543,"sdfff")
nano3 = car(20,2020,3432,"223432f34")
audiq75 = car(10,2020,4543,"sdfff")
nano6 = car(20,2020,3432,"223432f34")
audiq7678 = car(10,2020,4543,"sdfff")
nano67 = car(20,2020,3432,"223432f34")
audiq789 = car(10,2020,4543,"sdfff")
nano2 = car(20,2020,3432,"223432f34")
audiq754 = car(10,2020,4543,"sdfff")

# %%
class car:
    def __init__(a,milage,year,make,model):
        a.milage = milage
        a.year = year
        a.make  = make
        a.make = model

# %%
nano67.milage
# Out:
# 20

# %%
class car:
    def __init__(a,m,y,ma,mo):
        a.milage = m
        a.year = y
        a.make  = ma
        a.make = mo 
    
    
    def   age(b,current_year):
        return current_year - b.year
    
    
    def  milage1(self):
        print("print a milage of a car",self.milage)
        # return self.milage
        
    def __str__(c):
        return "this is my car class I  have created"

# %%
nano67 = car(20,2020,3432,"223432f34")

# %%
nano67.milage1()
# Out:
# print a milage of a car 20

# %%
nano67.milage
# Out:
# 20

# %%
nano67.age
# Out:
# <bound method car.age of <__main__.car object at 0x7f14f75bc5d0>>

# %%
nano67.age(2021)
# Out:
# 1

# %%
print(nano67)
# Out:
# this is my car class I  have created

# %%
print(nano67)
# Out:
# this is my car class I  have created

# %%
class student:
    def __init__(self,name,rollno,joining_date,current_topic):
        self.name  = name
        self.rollno = rollno
        self.joining_date = joining_date
        self.current_topic = current_topic
      
    def name_parsing(self):
        if type(self.name) == list:
            for i in self.name:
                print("name of the student",i)
        else:
            print("provided name is not in a form of list")
    
    
    def crt_topic(self):
        print("current topic discussed in my class is" , self.current_topic)
    
    def str_rollno(self):
        try:  
            if type(self.rollno) ==str:
                 print("do nothing")
            else:
                return  str(self.rollno)
        except  exception as e:
            print("this is my eror message")
    def  duration(self,current_date):
        print("duration of student in my class is",current_date-self.joining_date)
    def __str__(self):
        return  "this is strudent class where they try to input there ow data"

# %%
swetanshu = student("swetanshu",312753,2021,"oops")

# %%
swetanshu.duration(2021)
# Out:
# duration of student in my class is 0

# %%
swetanshu.str_rollno()
# Out:
# '312753'

# %%
print(swetanshu)
# Out:
# this is strudent class where they try to input there ow data

# %%
marur = student("marur","afdd", 3523,23432)

# %%
marur.crt_topic()
# Out:
# current topic discussed in my class is 23432

# %%
pawan = student(["naveen","jay","himanshu","prakash"],[234,233,213,343],2021,"oops")

# %%
pawan.name_parsing()
# Out:
# name of the student naveen
# name of the student jay
# name of the student himanshu
# name of the student prakash
