# %% [markdown]
# #      to jump to next cell

# %% [markdown]
# shift+enter

# %% [markdown]
# # features of python

# %%
### interpreted ,multi paradigm, open source , diversified, easy and simple , large standard library , dynamically typed

# %%
### 1....multi paradigm -----   imperative, functional  ,  procedural  ,object oriented

# %%
### 2 .. ..open source ------- free to download

# %%
### 3 ....diversified ------web devlopment , data analysis ,machine learning ,android app devlopment , etc.

# %%
#### 4....interpreted language ----- execute code line by line so we can check where is mistake

# %%
### 5....easy and simple ------- understand codes easier than other languages

# %%
#### 6.....dynamic typing ---- static type ,dyanamic type

# %%
#### 7 ....large statndard library ------ contains many functions inside it

# %% [markdown]
# # number and variables

# %% [markdown]
# ##  numbers

# %%
######   1....integers,,,,2.....floating point(4.5,3.4,etc)

# %% [markdown]
# ## operators

# %%
# addition 
2+3
# Out:
# 5

# %%
#subtraction
2-3
# Out:
# -1

# %%
#multiplication
2*3
# Out:
# 6

# %%
 #division 
2/4
# Out:
# 0.5

# %%
#floor division ---- we will get quotient not remainder
5//2
# Out:
# 2

# %%
# modulo division -------we will get only remainder
5%2
# Out:
# 1

# %%
# powers
2**3
# Out:
# 8

# %%
#powers
2**5
# Out:
# 32

# %% [markdown]
# #powers
# 7**3

# %%
#roots
2**0.5
8**(1/3)
# Out:
# 2.0

# %%
# orders  -----BODMAS

2-8*2+3
# Out:
# -11

# %% [markdown]
# ## variables

# %%
a = 5 
print(a)
# Out:
# 5

# %%
#2name = raj , swetanshu            #error as variable cannot start with number,

# %%
# my var =raj , swetanshu,,         #error as variable cant have space between them

# %% [markdown]
# ###  dynamic typing

# %%
a=44
print(a)
# Out:
# 44

# %%
#to determne the type of variable function

#type() -----is used

# %% [markdown]
# #  strings

# %%
#  '  '  or  '  " "  ' or " " any letter or sentence or paragraph  or word between double or single inverted comma can be termed as string

# %%
#'I didn't work'           #cant print as due  to single inverted comma

# %%
a =  "swetanshu"
a.upper()
# Out:
# 'SWETANSHU'

# %%
b ="LOWER"
b.lower()
# Out:
# 'lower'

# %%
C= "MY NAME IS SWETANSHU PANDEY"
C.split()
# Out:
# ['MY', 'NAME', 'IS', 'SWETANSHU', 'PANDEY']

# %%
d= "my name is swetanshu raj pandey"
d.split('s')
# Out:
# ['my name i', ' ', 'wetan', 'hu raj pandey']

# %%
len(d)            #space between words are also considerd as characters
# Out:
# 31

# %% [markdown]
# ### indexing

# %%
d[4]
# Out:
# 'a'

# %%
d[-2]                  # starts from last
# Out:
# 'e'

# %% [markdown]
# ### slicing

# %%
e= "swetanshu"

# %%
e[1:3]
# Out:
# 'we'

# %%
e[2:]
# Out:
# 'etanshu'

# %%
e[-1:]
# Out:
# 'u'

# %% [markdown]
# e[:-1]

# %%
e[1:4:2]
# Out:
# 'wt'

# %% [markdown]
#  ###  immutability

# %%
#property of an element in which oncean string is created  it cannot be interchanged..

# %%
e
# Out:
# 'swetanshu'

# %%
e[2] = "wer"          # immutability
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-4743779f87af> in <module>
# ----> 1 e[2] = "wer"          # immutability
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### concatenation

# %%
e = e  + " is superb "

# %%
e
# Out:
# 'swetanshu is superb '

# %%
f= e + " is superb "

# %%
f
# Out:
# 'swetanshu is superb  is superb '

# %%
g = 'b'

# %% [markdown]
# g*5

# %% [markdown]
# ### string formatting

# %%
#inject or add strings in a dynamic way

# %%
#1....    %s 
#2....    format()
#3....  f-string

# %% [markdown]
# ### 1 .....   %s

# %% [markdown]
# print(" I love working with %s")

# %%
print(" I love working with %s," %'python')
# Out:
#  I love working with python,

# %%
print("python is %s and %s," %('easy', 'simple'))
# Out:
# python is easy and simple,

# %%
print("I love {}".format("python"))
# Out:
# I love python

# %%
dish = 'dosa'

# %%
print(f"I love {dish}" )
# Out:
# I love dosa

# %% [markdown]
# # list

# %%
#1 ...list
#2....tuples.
#3.....dictionaries

# %%
# list is mutable, multiple data type can be put inside a list

# %%
my_list =  [1,3,5]

# %%
print(my_list)
# Out:
# [1, 3, 5]

# %%
new_list = ['b',34,2.4]

# %%
print(new_list)
# Out:
# ['b', 34, 2.4]

# %%
len(new_list)
# Out:
# 3

# %% [markdown]
# ###  indexing and slicing

# %%
new_list[1]
# Out:
# 34

# %%
new_list[1:3]
# Out:
# [34, 2.4]

# %%
q=new_list + [90]

# %%
q
# Out:
# ['b', 34, 2.4, 90]

# %%
### doubling the list

# %%
q*2
# Out:
# ['b', 34, 2.4, 90, 'b', 34, 2.4, 90]

# %%
 ### method of concatenation

# %%
q.append("python")
q
# Out:
# ['b', 34, 2.4, 90, 'python', 'python', 'python']

# %%
### method of removing

# %%
q.pop()
# Out:
# 'python'

# %%
q.pop(3)
# Out:
# 90

# %%
q
# Out:
# ['b', 34, 2.4, 'python', 'python']

# %%
### method to reverse

# %%
q.reverse()

# %%
q
# Out:
# ['python', 'python', 2.4, 34, 'b']

# %%
### method to sort  ------------ elements of same data type must be in the list

# %%
bbc= [3,4,5,6,7]

# %%
bbc.sort()       ### prints list in ascending order

# %%
bbc
# Out:
# [3, 4, 5, 6, 7]

# %%
### nested sort----------- enclose list inside another list

# %%
x = [2,3,4]

# %%
y = [ 1,1,1]

# %%
z = [2,4,6]

# %%
matrix = [x,y,z]

# %%
matrix
# Out:
# [[2, 3, 4], [1, 1, 1], [2, 4, 6]]

# %% [markdown]
# ##  tuples

# %%
### they are immutable means they cannot be changed  ,,  they are always written in ()

# %%
t = (1,2,3)

# %%
type(t)
# Out:
# tuple

# %%
t[2]
# Out:
# 3

# %%
t.index(2)
# Out:
# 1

# %%
## to check repeation in a list or tuple

# %%
e = (11,11,11,11,22,33,44,44,44,44,44)

# %%
e.count(11)
# Out:
# 4

# %%
####### tuple are immutable

# %%
e.append(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-5b14b3221b1b> in <module>
# ----> 1 e.append(2)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
#######   list uses square bracket [] ,,,, tuple uses paranthesis (),,,,dictionaries uses curley bracket {}......

# %%
#####  in dict for every value there should be a "key"

# %%
dict  =   {'key1':1,'key2':2,"key3":3,'key4':'a','key5':'abcdefgh'}

# %%
dict
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 'a', 'key5': 'abcdefgh'}

# %%
dict['key3']
# Out:
# 3

# %%
dict['key4']
# Out:
# 'a'

# %%
dict['key5'][4]
# Out:
# 'e'

# %%
dict2 = {'k1': 6,'k2':[1,2,3,4,5],'k3':1}

# %%
dict2
# Out:
# {'k1': 6, 'k2': [1, 2, 3, 4, 5], 'k3': 1}

# %%
dict2['k2']
# Out:
# [1, 2, 3, 4, 5]

# %%
#########  methods and properties of dictionaries

# %%
dict2['k1']-3   ##############  subtraction method
# Out:
# 3

# %%
type(dict2)
# Out:
# dict

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d['k1'] = 'add'

# %%
d['k2'] ='sub'

# %%
d
# Out:
# {'k1': 'add', 'k2': 'sub'}

# %%
######  nesting in dictionaries ,i.e,  we can place a dict inside a dict

# %%
d= {'k1':{'k2:8'}}

# %%
d
# Out:
# {'k1': {'k2:8'}}

# %%
dict.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3', 'key4', 'key5'])

# %%
dict.values()
# Out:
# dict_values([1, 2, 3, 'a', 'abcdefgh'])
