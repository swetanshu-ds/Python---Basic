# %%
a = 10
b =  20
a+b
# Out:
# 30

# %%
def test(x,y):
    pass
    print(x+y)

# %%
type(test)
# Out:
# function

# %%
type(test(23,45))
# Out:
# 68
# NoneType

# %%
test(4,6)
# Out:
# 10

# %%
test(1,4)
# Out:
# 5

# %%
def test1(b,m):
    return b*m

# %%
type(test1(5,89))
# Out:
# int

# %%
6+ test1(5,89)
# Out:
# 451

# %%
test(1,2) +6
# Out:
# 3

# %%
def test2(t,n,m):
    return  t+m

# %%
test2(2,3,4)
# Out:
# 6

# %%
def test3(n,m):
          return m*10,n*190,m+n,n/m

# %%
test3(8,4)
# Out:
# (40, 1520, 12, 2.0)

# %%
c,x,v,_= test3(2,4)

# %%
c
# Out:
# 40

# %%
v
# Out:
# 6

# %%
x
# Out:
# 380

# %%
_
# Out:
# 0.5

# %%
_,_,w,_ = test3(2,4)

# %%
_
# Out:
# 0.5

# %%
_
# Out:
# 0.5

# %%
 def test():
        print("this is my first class")

# %%
m = test()
# Out:
# this is my first class

# %%
m + "njcenjcne"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-b89488594552> in <module>
# ----> 1 m + "njcenjcne"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test():
    return "this is my first class"

# %%
 n =test()

# %%
n
# Out:
# 'this is my first class'

# %%
n +"   ncjebche"
# Out:
# 'this is my first class   ncjebche'

# %%
def test5(n):
    return n*2

# %%
test5([2,3,4,5,6,7])
# Out:
# [2, 3, 4, 5, 6, 7, 2, 3, 4, 5, 6, 7]

# %%
 test5(45)
# Out:
# 90

# %%
def test5(n):
    return n,n*9

# %%
test5([2,4,5,67])
# Out:
# ([2, 4, 5, 67],
#  [2,
#   4,
#   5,
#   67,
#   2,
#   4,
#   5,
#   67,
#   2,
#   4,
#   5,
#   67,
#   2,
#   4,
#   5,
#   67,
#   2,
#   4,
#   5,
#   67,
#   2,
#   4,
#   5,
#   67,
#   2,
#   4,
#   5,
#   67,
#   2,
#   4,
#   5,
#   67,
#   2,
#   4,
#   5,
#   67])

# %%
 def test6(n):
        return n,n*2

# %%
b = test6(([2,3,4],[3,4,5]))

# %%
b
# Out:
# (([2, 3, 4], [3, 4, 5]), ([2, 3, 4], [3, 4, 5], [2, 3, 4], [3, 4, 5]))

# %%
b[0]
# Out:
# ([2, 3, 4], [3, 4, 5])

# %%
def test7(n:30,m):
    return n+m

# %%
test7(30,60)
# Out:
# 90

# %%
def test8(n,m=90):
    return n+m

# %%
test8(60)
# Out:
# 150

# %%
def boolx(x = True, y = False):
    return x + y

# %%
boolx()
# Out:
# 1

# %%
boolx(False)
# Out:
# 0

# %%
boolx(True)
# Out:
# 1

# %%
boolx(False,8)
# Out:
# 8

# %%
True = 1+ False = 0
# Out:
#   File "<ipython-input-57-6a30789d9db1>", line 1
#     True = 1+ False = 0
#                        ^
# SyntaxError: can't assign to keyword

# %%
True + False
# Out:
# 1

# %%
def travel(bike = True, car = False):
    plan_travel = bike or car
    return bike, car, plan_travel

# %%
travel()
# Out:
# (True, False, True)

# %%
travel(car = True)
# Out:
# (True, True, True)

# %%
travel(_,True)
# Out:
# (((True, True, True), True, (True, True, True)),
#  True,
#  ((True, True, True), True, (True, True, True)))

# %%
* = steric
*args       #means we can paas many data in a arguments
# Out:
#   File "<ipython-input-2-1fe0beade7b0>", line 1
#     * = steric
#       ^
# SyntaxError: invalid syntax

# %%
def test11(*args):
    return args

# %%
test11("swetanshu","pandey", 334,[23,45,24,5,6,234])
# Out:
# ('swetanshu', 'pandey', 334, [23, 45, 24, 5, 6, 234])

# %%
def test12(n):
    return n

# %%
test12("swetanshu","pandey")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-538cab12f6d4> in <module>
# ----> 1 test12("swetanshu","pandey")
#
# TypeError: test12() takes 1 positional argument but 2 were given

# %%
def myfunc(*args):
    return  args

# %%
myfunc("swetansh","raj", 2,3,4,5,1)
# Out:
# ('swetansh', 'raj', 2, 3, 4, 5, 1)

# %%
myfunc("swetanshu","rsj","pandey","foul",1,2,3,4,5,6,7,8,9,0)
# Out:
# ('swetanshu', 'rsj', 'pandey', 'foul', 1, 2, 3, 4, 5, 6, 7, 8, 9, 0)

# %%
def test13(*args):
    l = []
    for i in args:
        l.append(i)
    return l

# %%
test13([3,4,5],[3,4,5,6,7],[1.34])
# Out:
# [[3, 4, 5], [3, 4, 5, 6, 7], [1.34]]

# %%
def test13(*args):
    l = []
    for i in args:
        l = l+i
    return l

# %%
test13([3,4,5],[3,4,5,6,7],[1.34])
# Out:
# [3, 4, 5, 3, 4, 5, 6, 7, 1.34]

# %%
test13([2,45,6],[7,8,9])
# Out:
# [2, 45, 6, 7, 8, 9]

# %%
def test14(*args):
    return[i for i in args]

# %%
test14([4,5,6],[5,6,7])
# Out:
# [[4, 5, 6], [5, 6, 7]]

# %%
#kwargs = key words arguments as it only  takes  key and value and any number of arguments
# but accepts only argument which are available in key ad value 
def test16(**kwargs):
      return kwargs

# %%
test16(2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-3a41af59fe7d> in <module>
# ----> 1 test16(2,3,4)
#
# TypeError: test16() takes 0 positional arguments but 3 were given

# %%
test16(a= 16,b = 5)
# Out:
# {'a': 16, 'b': 5}

# %%
type(test16)
# Out:
# function

# %%
def test17(**kwargs):
    return kwargs

# %%
test17(a= 2,b= 4, c= [2,3,4,"kumar"])
# Out:
# {'a': 2, 'b': 4, 'c': [2, 3, 4, 'kumar']}

# %%
def func2(*args,**kwargs):
    l = [i for i in args]
    d = [i[1] for i in kwargs.items() if type(i[1])==list]
    return l,d

# %%
func2([4,5,6,7,8],[5,6,7,8,9],1,2,3,4,5,6,7,a= 5,b= "jcbhbc",n = [1,2,3,4,5,6])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-78dc7d058712> in <module>
# ----> 1 func2([4,5,6,7,8],[5,6,7,8,9],1,2,3,4,5,6,7,a= 5,b= "jcbhbc",n = [1,2,3,4,5,6])
#
# NameError: name 'func2' is not defined

# %%
def test18(**kwargs):
    for i in kwargs.items():
        if type(i[1])== list:
            if "swe" in i[1]:
                print("i am able tofind yor name in inpt data")
                print(i)
    return kwargs

# %%
test18(a=1,b=2,c=3,d=["swetanshu","kumar","pandey"],e= 6+5j)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': ['swetanshu', 'kumar', 'pandey'], 'e': (6+5j)}
